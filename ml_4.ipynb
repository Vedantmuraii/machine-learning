# %%
import pandas as pd
import os

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
dataframe=pd.read_csv('SN_AD.xls')

# %%
dataframe.head(5)
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
dataframe.tail(5)
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1

# %%
dataframe.shape
# Out:
# (400, 5)

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   User ID          400 non-null    int64
#  1   Gender           400 non-null    object
#  2   Age              400 non-null    int64
#  3   EstimatedSalary  400 non-null    int64
#  4   Purchased        400 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 15.8+ KB

# %%
dataframe.drop(['User ID',], inplace=True, axis=1)

# %%
data=dataframe.drop('Gender',axis='columns')

# %%
#data.Sex=data.Sex.replace("male",0)
#data.Sex=data.Sex.replace("female",1)

# %%
data.shape
# Out:
# (400, 3)

# %%
data.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
import seaborn as sns
plt.figure()
sns.pairplot(dataframe,hue="Purchased",markers=['o','s'])
plt.show()

# %%
sns.jointplot(x='Gender',y='Purchased',data=dataframe,kind='reg')
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-23-0a080f81e229> in <cell line: 1>()
# ----> 1 sns.jointplot(x='Gender',y='Purchased',data=dataframe,kind='reg')
#
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2322
#    2323         joint_kws.setdefault("color", color)
# -> 2324         grid.plot_joint(regplot, **joint_kws)
#    2325
#    2326     elif kind.startswith("resid"):
#
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py in plot_joint(self, func, **kwargs)
#    1824
#    1825         if str(func.__module__).startswith("seaborn"):
# -> 1826             func(x=self.x, y=self.y, **kwargs)
#    1827         else:
# ...

# %%
x=dataframe.drop(["Purchased","Gender"],axis="columns")
y=dataframe.drop(["Gender","Age","EstimatedSalary"],axis="columns")

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
# x dependent , y indepenndent

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
from sklearn.neighbors import KNeighborsClassifier
classifier=KNeighborsClassifier(n_neighbors=7)

# %%
classifier.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_pred=classifier.predict(x_test)

# %%
classifier.score(x_test,y_test)
# Out:
# 0.8

# %%
x_train.shape
# Out:
# (320, 2)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_tyrain,y_test=train_test_split(x,y,test_size=0.2,random_state=15)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
from sklearn.neighbors import KNeighborsClassifier
classifier=KNeighborsClassifier(n_neighbors=7)

# %%
classifier.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
classifier.score(x_test,y_test)
# Out:
# 0.5375
